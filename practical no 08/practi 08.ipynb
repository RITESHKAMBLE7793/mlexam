# %%
 #8. Develop a Gradient Boosting regression model to predict carbon monoxide (CO)
#concentration based on meteorological and sensor data using the Air Quality Dataset (UCI).
#Handle missing values, perform appropriate feature scaling, and evaluate the model’s
#performance using MSE, MAE, RMSE, and R-squared metrics to ensure accurate prediction
#of air pollutant levels.
#Dataset: Air Quality Dataset (UCI).

# %%
# Step 1: Import Libraries

import pandas as pd
import numpy as np

from sklearn.impute import SimpleImputer
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score

# %%
# Step 2: Load Dataset

data = pd.read_csv("AirQualityUCI.csv")

print(data.head())
# Out:
#          Date      Time  CO(GT)  PT08.S1(CO)  NMHC(GT)  C6H6(GT)  \
# 0  10-03-2004  18:00:00     2.6       1360.0     150.0      11.9
# 1  10-03-2004  19:00:00     2.0       1292.0     112.0       9.4
# 2  10-03-2004  20:00:00     2.2       1402.0      88.0       9.0
# 3  10-03-2004  21:00:00     2.2       1376.0      80.0       9.2
# 4  10-03-2004  22:00:00     1.6       1272.0      51.0       6.5
#
#    PT08.S2(NMHC)  NOx(GT)  PT08.S3(NOx)  NO2(GT)  PT08.S4(NO2)  PT08.S5(O3)  \
# 0         1046.0    166.0        1056.0    113.0        1692.0       1268.0
# 1          955.0    103.0        1174.0     92.0        1559.0        972.0
# 2          939.0    131.0        1140.0    114.0        1555.0       1074.0
# 3          948.0    172.0        1092.0    122.0        1584.0       1203.0
# 4          836.0    131.0        1205.0    116.0        1490.0       1110.0
#
#       T    RH      AH  Unnamed: 15  Unnamed: 16
# 0  13.6  48.9  0.7578          NaN          NaN
# ...

# %%
# Step 3: Check Columns

print(data.columns)
# Out:
# Index(['Date', 'Time', 'CO(GT)', 'PT08.S1(CO)', 'NMHC(GT)', 'C6H6(GT)',
#        'PT08.S2(NMHC)', 'NOx(GT)', 'PT08.S3(NOx)', 'NO2(GT)', 'PT08.S4(NO2)',
#        'PT08.S5(O3)', 'T', 'RH', 'AH', 'Unnamed: 15', 'Unnamed: 16'],
#       dtype='object')

# %%
# Step 4: Remove Empty Columns

data.drop(
    columns=['Unnamed: 15', 'Unnamed: 16'],
    inplace=True,
    errors='ignore'
)

# %%
# Step 5: Replace Missing Values (-200)

data.replace(-200, np.nan, inplace=True)

# %%
# Step 6: Convert Columns to Numeric

for col in data.columns:
    data[col] = pd.to_numeric(data[col], errors='ignore')
# Out:
# C:\Users\kambl\AppData\Local\Temp\ipykernel_22688\734723946.py:4: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_numeric without passing `errors` and catch exceptions explicitly instead
#   data[col] = pd.to_numeric(data[col], errors='ignore')

# %%
# Step 7: Select Numeric Columns

numeric_data = data.select_dtypes(include=np.number)

print(numeric_data.columns)
# Out:
# Index(['CO(GT)', 'PT08.S1(CO)', 'NMHC(GT)', 'C6H6(GT)', 'PT08.S2(NMHC)',
#        'NOx(GT)', 'PT08.S3(NOx)', 'NO2(GT)', 'PT08.S4(NO2)', 'PT08.S5(O3)',
#        'T', 'RH', 'AH'],
#       dtype='object')

# %%
# Step 7: Select Numeric Columns

numeric_data = data.select_dtypes(include=np.number)

print(numeric_data.columns)
# Out:
# Index(['CO(GT)', 'PT08.S1(CO)', 'NMHC(GT)', 'C6H6(GT)', 'PT08.S2(NMHC)',
#        'NOx(GT)', 'PT08.S3(NOx)', 'NO2(GT)', 'PT08.S4(NO2)', 'PT08.S5(O3)',
#        'T', 'RH', 'AH', 'Unnamed: 15', 'Unnamed: 16'],
#       dtype='object')

# %%
# Step 8: Remove Fully Empty Columns

numeric_data = numeric_data.dropna(axis=1, how='all')

# %%
import numpy as np

data.replace(-200, np.nan, inplace=True)

# %%
numeric_data = data.select_dtypes(include=np.number)

print(numeric_data.columns)
# Out:
# Index(['CO(GT)', 'PT08.S1(CO)', 'NMHC(GT)', 'C6H6(GT)', 'PT08.S2(NMHC)',
#        'NOx(GT)', 'PT08.S3(NOx)', 'NO2(GT)', 'PT08.S4(NO2)', 'PT08.S5(O3)',
#        'T', 'RH', 'AH'],
#       dtype='object')

# %%
from sklearn.impute import SimpleImputer

imputer = SimpleImputer(strategy='mean')

data_imputed = pd.DataFrame(
    imputer.fit_transform(numeric_data),
    columns=numeric_data.columns
)

print(data_imputed.head())
# Out:
#    CO(GT)  PT08.S1(CO)  NMHC(GT)  C6H6(GT)  PT08.S2(NMHC)  NOx(GT)  \
# 0     2.6       1360.0     150.0      11.9         1046.0    166.0
# 1     2.0       1292.0     112.0       9.4          955.0    103.0
# 2     2.2       1402.0      88.0       9.0          939.0    131.0
# 3     2.2       1376.0      80.0       9.2          948.0    172.0
# 4     1.6       1272.0      51.0       6.5          836.0    131.0
#
#    PT08.S3(NOx)  NO2(GT)  PT08.S4(NO2)  PT08.S5(O3)     T    RH      AH
# 0        1056.0    113.0        1692.0       1268.0  13.6  48.9  0.7578
# 1        1174.0     92.0        1559.0        972.0  13.3  47.7  0.7255
# 2        1140.0    114.0        1555.0       1074.0  11.9  54.0  0.7502
# 3        1092.0    122.0        1584.0       1203.0  11.0  60.0  0.7867
# 4        1205.0    116.0        1490.0       1110.0  11.2  59.6  0.7888

# %%
y = data_imputed['CO(GT)']

X = data_imputed.drop('CO(GT)', axis=1)

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()

X_scaled = scaler.fit_transform(X)

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(
    X_scaled,
    y,
    test_size=0.2,
    random_state=42
)

# %%
from sklearn.ensemble import GradientBoostingRegressor

model = GradientBoostingRegressor(
    n_estimators=100,
    learning_rate=0.1,
    random_state=42
)

model.fit(X_train, y_train)
# Out:
# GradientBoostingRegressor(random_state=42)

# %%
y_pred = model.predict(X_test)

# %%
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score
import numpy as np

mse = mean_squared_error(y_test, y_pred)
mae = mean_absolute_error(y_test, y_pred)
rmse = np.sqrt(mse)
r2 = r2_score(y_test, y_pred)

print("MSE =", mse)
print("MAE =", mae)
print("RMSE =", rmse)
print("R2 Score =", r2)
# Out:
# MSE = 0.3057436672238107
# MAE = 0.36857936934705066
# RMSE = 0.5529409256184703
# R2 Score = 0.8269921059217643
